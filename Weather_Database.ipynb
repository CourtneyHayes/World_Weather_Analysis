# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #city_description = city_weather[["weather"]["description"]]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
                          #"Current Description": city_description
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | medicine hat
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | griffith
# Processing Record 10 of Set 1 | bairiki
# Processing Record 11 of Set 1 | taltal
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | aranos
# Processing Record 14 of Set 1 | grinnell
# Processing Record 15 of Set 1 | dunedin
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | christchurch
# Processing Record 19 of Set 1 | krasni okny
# Processing Record 20 of Set 1 | isangel
# Processing Record 21 of Set 1 | hambantota
# Processing Record 22 of Set 1 | sobolevo
# Processing Record 23 of Set 1 | robertsport
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | clyde river
# Processing Record 26 of Set 1 | cocobeach
# Processing Record 27 of Set 1 | nome
# Processing Record 28 of Set 1 | lompoc
# Processing Record 29 of Set 1 | saint george
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | mala
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | tres arroyos
# Processing Record 39 of Set 1 | high level
# Processing Record 40 of Set 1 | lyuban
# Processing Record 41 of Set 1 | tabuk
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | ruwi
# Processing Record 46 of Set 1 | ust-tsilma
# Processing Record 47 of Set 1 | vysokogornyy
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | dombarovskiy
# Processing Record 1 of Set 2 | sotik
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | baruun-urt
# Processing Record 4 of Set 2 | sioux lookout
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | mount gambier
# Processing Record 9 of Set 2 | kruisfontein
# Processing Record 10 of Set 2 | phalaborwa
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | bhag
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | saldanha
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | chifeng
# Processing Record 17 of Set 2 | cayenne
# Processing Record 18 of Set 2 | kutum
# Processing Record 19 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 23 of Set 2 | great yarmouth
# Processing Record 24 of Set 2 | deputatskiy
# Processing Record 25 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | san cristobal
# Processing Record 28 of Set 2 | sept-iles
# Processing Record 29 of Set 2 | imbituba
# Processing Record 30 of Set 2 | khilok
# Processing Record 31 of Set 2 | ust-nera
# Processing Record 32 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 2 | port hawkesbury
# Processing Record 34 of Set 2 | ngunguru
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | mugur-aksy
# Processing Record 37 of Set 2 | vestbygda
# City not found. Skipping...
# Processing Record 38 of Set 2 | erenhot
# Processing Record 39 of Set 2 | pevek
# Processing Record 40 of Set 2 | dera ghazi khan
# Processing Record 41 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 42 of Set 2 | kattivakkam
# Processing Record 43 of Set 2 | simav
# Processing Record 44 of Set 2 | laela
# Processing Record 45 of Set 2 | katsuura
# Processing Record 46 of Set 2 | churachandpur
# Processing Record 47 of Set 2 | lavrentiya
# Processing Record 48 of Set 2 | alofi
# Processing Record 49 of Set 2 | port arthur
# Processing Record 50 of Set 2 | copiapo
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | igrim
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | odda
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | khatanga
# Processing Record 7 of Set 3 | severo-yeniseyskiy
# Processing Record 8 of Set 3 | nantucket
# Processing Record 9 of Set 3 | staroaleyskoye
# Processing Record 10 of Set 3 | lokoja
# Processing Record 11 of Set 3 | hithadhoo
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | bandarbeyla
# Processing Record 14 of Set 3 | lorengau
# Processing Record 15 of Set 3 | haines junction
# Processing Record 16 of Set 3 | zaozerne
# Processing Record 17 of Set 3 | dobsina
# Processing Record 18 of Set 3 | tasiilaq
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | cape town
# Processing Record 21 of Set 3 | lagoa nova
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | stornoway
# Processing Record 24 of Set 3 | bayshore gardens
# Processing Record 25 of Set 3 | tual
# Processing Record 26 of Set 3 | havelock
# Processing Record 27 of Set 3 | juneau
# Processing Record 28 of Set 3 | sechura
# Processing Record 29 of Set 3 | saskylakh
# Processing Record 30 of Set 3 | sao joao da barra
# Processing Record 31 of Set 3 | maxixe
# Processing Record 32 of Set 3 | carlsbad
# Processing Record 33 of Set 3 | urucui
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | fengkou
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | ponta do sol
# Processing Record 39 of Set 3 | menzelinsk
# Processing Record 40 of Set 3 | jalu
# Processing Record 41 of Set 3 | okhotsk
# Processing Record 42 of Set 3 | hermanus
# Processing Record 43 of Set 3 | naze
# Processing Record 44 of Set 3 | cockburn town
# Processing Record 45 of Set 3 | owerri
# Processing Record 46 of Set 3 | kulhudhuffushi
# Processing Record 47 of Set 3 | bubaque
# Processing Record 48 of Set 3 | rikitea
# Processing Record 49 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 3 | madras
# Processing Record 1 of Set 4 | daru
# Processing Record 2 of Set 4 | rocha
# Processing Record 3 of Set 4 | ambilobe
# Processing Record 4 of Set 4 | mao
# Processing Record 5 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 4 | alwar tirunagari
# Processing Record 7 of Set 4 | honiara
# Processing Record 8 of Set 4 | treinta y tres
# Processing Record 9 of Set 4 | elko
# Processing Record 10 of Set 4 | praia da vitoria
# Processing Record 11 of Set 4 | ondjiva
# Processing Record 12 of Set 4 | batagay
# Processing Record 13 of Set 4 | borogontsy
# Processing Record 14 of Set 4 | maniitsoq
# Processing Record 15 of Set 4 | vestmannaeyjar
# Processing Record 16 of Set 4 | buala
# Processing Record 17 of Set 4 | necochea
# Processing Record 18 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 4 | tiksi
# Processing Record 20 of Set 4 | korablino
# Processing Record 21 of Set 4 | talnakh
# Processing Record 22 of Set 4 | piacabucu
# Processing Record 23 of Set 4 | ostrovnoy
# Processing Record 24 of Set 4 | bastia
# Processing Record 25 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 26 of Set 4 | zhigansk
# Processing Record 27 of Set 4 | bathsheba
# Processing Record 28 of Set 4 | salalah
# Processing Record 29 of Set 4 | east london
# Processing Record 30 of Set 4 | santa isabel do rio negro
# Processing Record 31 of Set 4 | young
# Processing Record 32 of Set 4 | kutoarjo
# Processing Record 33 of Set 4 | leningradskiy
# Processing Record 34 of Set 4 | puerto colombia
# Processing Record 35 of Set 4 | portland
# Processing Record 36 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 4 | henties bay
# Processing Record 38 of Set 4 | ixtapa
# Processing Record 39 of Set 4 | sasaram
# Processing Record 40 of Set 4 | husavik
# Processing Record 41 of Set 4 | vardo
# Processing Record 42 of Set 4 | tawnat
# City not found. Skipping...
# Processing Record 43 of Set 4 | davila
# Processing Record 44 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 4 | dingle
# Processing Record 46 of Set 4 | nioro
# Processing Record 47 of Set 4 | sao filipe
# Processing Record 48 of Set 4 | bredasdorp
# Processing Record 49 of Set 4 | grindavik
# Processing Record 50 of Set 4 | tahoua
# Processing Record 1 of Set 5 | bury saint edmunds
# City not found. Skipping...
# Processing Record 2 of Set 5 | matagami
# Processing Record 3 of Set 5 | norman wells
# Processing Record 4 of Set 5 | atuona
# Processing Record 5 of Set 5 | bambous virieux
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | zhicheng
# Processing Record 10 of Set 5 | prince rupert
# Processing Record 11 of Set 5 | marawi
# Processing Record 12 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 5 | tabou
# Processing Record 14 of Set 5 | faya
# Processing Record 15 of Set 5 | provideniya
# Processing Record 16 of Set 5 | ust-kut
# Processing Record 17 of Set 5 | sembe
# Processing Record 18 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 5 | srikakulam
# Processing Record 20 of Set 5 | moussoro
# Processing Record 21 of Set 5 | myre
# Processing Record 22 of Set 5 | iralaya
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | taywarah
# Processing Record 25 of Set 5 | namatanai
# Processing Record 26 of Set 5 | quelimane
# Processing Record 27 of Set 5 | saint-philippe
# Processing Record 28 of Set 5 | paamiut
# Processing Record 29 of Set 5 | iracoubo
# Processing Record 30 of Set 5 | carnarvon
# Processing Record 31 of Set 5 | tadine
# Processing Record 32 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 5 | hualmay
# Processing Record 34 of Set 5 | hasaki
# Processing Record 35 of Set 5 | tessalit
# Processing Record 36 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 5 | araouane
# Processing Record 38 of Set 5 | turukhansk
# Processing Record 39 of Set 5 | caravelas
# Processing Record 40 of Set 5 | kajaani
# Processing Record 41 of Set 5 | xinmin
# Processing Record 42 of Set 5 | hargeysa
# Processing Record 43 of Set 5 | nerchinskiy zavod
# Processing Record 44 of Set 5 | lashio
# Processing Record 45 of Set 5 | nanortalik
# Processing Record 46 of Set 5 | port augusta
# Processing Record 47 of Set 5 | pontianak
# Processing Record 48 of Set 5 | asgabat
# Processing Record 49 of Set 5 | mikhaylovka
# Processing Record 50 of Set 5 | dungarpur
# Processing Record 1 of Set 6 | touros
# Processing Record 2 of Set 6 | iquitos
# Processing Record 3 of Set 6 | de-kastri
# Processing Record 4 of Set 6 | asasa
# Processing Record 5 of Set 6 | camana
# Processing Record 6 of Set 6 | cherskiy
# Processing Record 7 of Set 6 | gitega
# Processing Record 8 of Set 6 | poum
# Processing Record 9 of Set 6 | ahipara
# Processing Record 10 of Set 6 | taburao
# City not found. Skipping...
# Processing Record 11 of Set 6 | mattru
# Processing Record 12 of Set 6 | zambrano
# Processing Record 13 of Set 6 | gualeguay
# Processing Record 14 of Set 6 | fleet
# Processing Record 15 of Set 6 | dzhebariki-khaya
# Processing Record 16 of Set 6 | bengkulu
# Processing Record 17 of Set 6 | narasannapeta
# Processing Record 18 of Set 6 | alice springs
# Processing Record 19 of Set 6 | sorong
# Processing Record 20 of Set 6 | derac
# Processing Record 21 of Set 6 | verkhnevilyuysk
# Processing Record 22 of Set 6 | ancud
# Processing Record 23 of Set 6 | vostok
# Processing Record 24 of Set 6 | biltine
# Processing Record 25 of Set 6 | sile
# Processing Record 26 of Set 6 | muravlenko
# Processing Record 27 of Set 6 | cabo san lucas
# Processing Record 28 of Set 6 | barranca
# Processing Record 29 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 30 of Set 6 | okha
# Processing Record 31 of Set 6 | itarema
# Processing Record 32 of Set 6 | tuatapere
# Processing Record 33 of Set 6 | ha tinh
# Processing Record 34 of Set 6 | fukue
# Processing Record 35 of Set 6 | quartucciu
# Processing Record 36 of Set 6 | watsa
# Processing Record 37 of Set 6 | oak harbor
# Processing Record 38 of Set 6 | kavieng
# Processing Record 39 of Set 6 | swan hill
# Processing Record 40 of Set 6 | ikom
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | kahului
# Processing Record 43 of Set 6 | bambanglipuro
# Processing Record 44 of Set 6 | puerto del rosario
# Processing Record 45 of Set 6 | hohhot
# Processing Record 46 of Set 6 | san patricio
# Processing Record 47 of Set 6 | opuwo
# Processing Record 48 of Set 6 | vila
# Processing Record 49 of Set 6 | seoul
# Processing Record 50 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 7 | kodiak
# Processing Record 2 of Set 7 | wampusirpi
# City not found. Skipping...
# Processing Record 3 of Set 7 | shirvan
# Processing Record 4 of Set 7 | berlevag
# Processing Record 5 of Set 7 | mayor pablo lagerenza
# Processing Record 6 of Set 7 | montepuez
# Processing Record 7 of Set 7 | cache creek
# Processing Record 8 of Set 7 | zeya
# Processing Record 9 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 7 | peniche
# Processing Record 11 of Set 7 | fuerte
# Processing Record 12 of Set 7 | sitka
# Processing Record 13 of Set 7 | sao joao
# Processing Record 14 of Set 7 | nautla
# Processing Record 15 of Set 7 | russell
# Processing Record 16 of Set 7 | chikoy
# City not found. Skipping...
# Processing Record 17 of Set 7 | granada
# Processing Record 18 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 7 | cortes
# Processing Record 20 of Set 7 | ust-maya
# Processing Record 21 of Set 7 | quatre cocos
# Processing Record 22 of Set 7 | leninskoye
# Processing Record 23 of Set 7 | harbour breton
# Processing Record 24 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 7 | kilingi-nomme
# Processing Record 26 of Set 7 | comodoro rivadavia
# Processing Record 27 of Set 7 | kanniyakumari
# Processing Record 28 of Set 7 | auki
# Processing Record 29 of Set 7 | loanda
# Processing Record 30 of Set 7 | guerrero negro
# Processing Record 31 of Set 7 | tuchola
# Processing Record 32 of Set 7 | krasnyy chikoy
# Processing Record 33 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 7 | chico
# Processing Record 36 of Set 7 | fairbanks
# Processing Record 37 of Set 7 | camacha
# Processing Record 38 of Set 7 | urumqi
# Processing Record 39 of Set 7 | beringovskiy
# Processing Record 40 of Set 7 | ampanihy
# Processing Record 41 of Set 7 | ilulissat
# Processing Record 42 of Set 7 | kijang
# Processing Record 43 of Set 7 | asau
# Processing Record 44 of Set 7 | biloela
# Processing Record 45 of Set 7 | broken hill
# Processing Record 46 of Set 7 | kamaishi
# Processing Record 47 of Set 7 | nago
# Processing Record 48 of Set 7 | aykhal
# Processing Record 49 of Set 7 | novyye gorki
# Processing Record 50 of Set 7 | chapais
# Processing Record 1 of Set 8 | zhangjiakou
# Processing Record 2 of Set 8 | tocantinopolis
# City not found. Skipping...
# Processing Record 3 of Set 8 | charters towers
# Processing Record 4 of Set 8 | novikovo
# Processing Record 5 of Set 8 | alice
# Processing Record 6 of Set 8 | arraial do cabo
# Processing Record 7 of Set 8 | bowen
# Processing Record 8 of Set 8 | aktash
# Processing Record 9 of Set 8 | vila velha
# Processing Record 10 of Set 8 | pyaozerskiy
# Processing Record 11 of Set 8 | college
# Processing Record 12 of Set 8 | kalmunai
# Processing Record 13 of Set 8 | port elizabeth
# Processing Record 14 of Set 8 | jardim
# Processing Record 15 of Set 8 | sao sebastiao
# Processing Record 16 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 8 | narsaq
# Processing Record 18 of Set 8 | junction city
# Processing Record 19 of Set 8 | saint-pierre
# Processing Record 20 of Set 8 | labuhan
# Processing Record 21 of Set 8 | huanren
# Processing Record 22 of Set 8 | kuytun
# Processing Record 23 of Set 8 | suntar
# Processing Record 24 of Set 8 | luderitz
# Processing Record 25 of Set 8 | hobyo
# Processing Record 26 of Set 8 | putina
# Processing Record 27 of Set 8 | oskemen
# Processing Record 28 of Set 8 | baboua
# City not found. Skipping...
# Processing Record 29 of Set 8 | singarayakonda
# Processing Record 30 of Set 8 | mineros
# Processing Record 31 of Set 8 | port blair
# Processing Record 32 of Set 8 | presidente epitacio
# Processing Record 33 of Set 8 | visby
# Processing Record 34 of Set 8 | kaduna
# Processing Record 35 of Set 8 | gamba
# Processing Record 36 of Set 8 | peleduy
# Processing Record 37 of Set 8 | manzhouli
# Processing Record 38 of Set 8 | sabang
# Processing Record 39 of Set 8 | santa
# Processing Record 40 of Set 8 | kaitangata
# Processing Record 41 of Set 8 | broome
# Processing Record 42 of Set 8 | san quintin
# Processing Record 43 of Set 8 | klaksvik
# Processing Record 44 of Set 8 | kaeo
# Processing Record 45 of Set 8 | maragogi
# Processing Record 46 of Set 8 | lewiston
# Processing Record 47 of Set 8 | horconcitos
# Processing Record 48 of Set 8 | olafsvik
# Processing Record 49 of Set 8 | miquelon
# Processing Record 50 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 9 | carmichael
# Processing Record 2 of Set 9 | jawhar
# Processing Record 3 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 4 of Set 9 | azambuja
# Processing Record 5 of Set 9 | geraldton
# Processing Record 6 of Set 9 | port macquarie
# Processing Record 7 of Set 9 | codrington
# Processing Record 8 of Set 9 | marinette
# Processing Record 9 of Set 9 | anadyr
# Processing Record 10 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 9 | santo antonio do ica
# Processing Record 12 of Set 9 | perth
# Processing Record 13 of Set 9 | tartki
# City not found. Skipping...
# Processing Record 14 of Set 9 | hofn
# Processing Record 15 of Set 9 | biak
# Processing Record 16 of Set 9 | mizan teferi
# Processing Record 17 of Set 9 | winslow
# Processing Record 18 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 9 | nipawin
# Processing Record 20 of Set 9 | lahij
# Processing Record 21 of Set 9 | mahibadhoo
# Processing Record 22 of Set 9 | pangnirtung
# Processing Record 23 of Set 9 | viedma
# Processing Record 24 of Set 9 | dalbandin
# Processing Record 25 of Set 9 | marystown
# Processing Record 26 of Set 9 | shingu
# Processing Record 27 of Set 9 | tuy hoa
# Processing Record 28 of Set 9 | gao
# Processing Record 29 of Set 9 | san policarpo
# Processing Record 30 of Set 9 | sorland
# Processing Record 31 of Set 9 | yala
# Processing Record 32 of Set 9 | raudeberg
# Processing Record 33 of Set 9 | beyneu
# Processing Record 34 of Set 9 | salinas
# Processing Record 35 of Set 9 | lata
# Processing Record 36 of Set 9 | hamilton
# Processing Record 37 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 9 | beloha
# Processing Record 39 of Set 9 | rundu
# Processing Record 40 of Set 9 | liminangcong
# City not found. Skipping...
# Processing Record 41 of Set 9 | coihaique
# Processing Record 42 of Set 9 | constitucion
# Processing Record 43 of Set 9 | san pedro
# Processing Record 44 of Set 9 | ayutla
# Processing Record 45 of Set 9 | japura
# Processing Record 46 of Set 9 | jizan
# Processing Record 47 of Set 9 | blagodatnoye
# Processing Record 48 of Set 9 | donskoye
# Processing Record 49 of Set 9 | buraydah
# Processing Record 50 of Set 9 | asyut
# Processing Record 1 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 10 | sisimiut
# Processing Record 3 of Set 10 | puerto baquerizo moreno
# Processing Record 4 of Set 10 | riyadh
# Processing Record 5 of Set 10 | artyom
# Processing Record 6 of Set 10 | waitati
# Processing Record 7 of Set 10 | cidreira
# Processing Record 8 of Set 10 | whitehorse
# Processing Record 9 of Set 10 | saint-louis
# Processing Record 10 of Set 10 | dortyol
# Processing Record 11 of Set 10 | aswan
# Processing Record 12 of Set 10 | iranshahr
# Processing Record 13 of Set 10 | chicama
# Processing Record 14 of Set 10 | gat
# Processing Record 15 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 10 | kirakira
# Processing Record 17 of Set 10 | souillac
# Processing Record 18 of Set 10 | columbus
# Processing Record 19 of Set 10 | skjervoy
# Processing Record 20 of Set 10 | miram shah
# Processing Record 21 of Set 10 | hirado
# Processing Record 22 of Set 10 | marzuq
# Processing Record 23 of Set 10 | atar
# Processing Record 24 of Set 10 | guajara-mirim
# City not found. Skipping...
# Processing Record 25 of Set 10 | laguna
# Processing Record 26 of Set 10 | carutapera
# Processing Record 27 of Set 10 | tautira
# Processing Record 28 of Set 10 | arlit
# Processing Record 29 of Set 10 | yagodnoye
# Processing Record 30 of Set 10 | poltavka
# Processing Record 31 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 10 | huilong
# Processing Record 33 of Set 10 | matata
# Processing Record 34 of Set 10 | soubre
# Processing Record 35 of Set 10 | oudtshoorn
# Processing Record 36 of Set 10 | palmer
# Processing Record 37 of Set 10 | madingou
# Processing Record 38 of Set 10 | umm lajj
# Processing Record 39 of Set 10 | inhambane
# Processing Record 40 of Set 10 | ajaccio
# Processing Record 41 of Set 10 | gari
# Processing Record 42 of Set 10 | stromness
# Processing Record 43 of Set 10 | manica
# Processing Record 44 of Set 10 | bodden town
# Processing Record 45 of Set 10 | atikokan
# Processing Record 46 of Set 10 | adrar
# Processing Record 47 of Set 10 | noyabrsk
# Processing Record 48 of Set 10 | saint-joseph
# Processing Record 49 of Set 10 | whitley bay
# Processing Record 50 of Set 10 | guantanamo
# Processing Record 1 of Set 11 | along
# Processing Record 2 of Set 11 | zapolyarnyy
# Processing Record 3 of Set 11 | toktogul
# Processing Record 4 of Set 11 | chebsara
# Processing Record 5 of Set 11 | lumphat
# Processing Record 6 of Set 11 | te anau
# Processing Record 7 of Set 11 | katobu
# Processing Record 8 of Set 11 | at-bashi
# Processing Record 9 of Set 11 | inirida
# Processing Record 10 of Set 11 | atasu
# Processing Record 11 of Set 11 | hovd
# Processing Record 12 of Set 11 | arica
# Processing Record 13 of Set 11 | seymchan
# Processing Record 14 of Set 11 | zhangzhou
# Processing Record 15 of Set 11 | chernyshevskiy
# Processing Record 16 of Set 11 | port lincoln
# Processing Record 17 of Set 11 | yar-sale
# Processing Record 18 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 11 | burnie
# Processing Record 20 of Set 11 | kununurra
# Processing Record 21 of Set 11 | kisangani
# Processing Record 22 of Set 11 | makokou
# Processing Record 23 of Set 11 | morant bay
# Processing Record 24 of Set 11 | richards bay
# Processing Record 25 of Set 11 | roma
# Processing Record 26 of Set 11 | kasongo-lunda
# Processing Record 27 of Set 11 | silopi
# Processing Record 28 of Set 11 | claremore
# Processing Record 29 of Set 11 | fort nelson
# Processing Record 30 of Set 11 | san lawrenz
# Processing Record 31 of Set 11 | los llanos de aridane
# Processing Record 32 of Set 11 | mango
# Processing Record 33 of Set 11 | dicabisagan
# Processing Record 34 of Set 11 | aransas pass
# Processing Record 35 of Set 11 | shemonaikha
# Processing Record 36 of Set 11 | wolmaranstad
# City not found. Skipping...
# Processing Record 37 of Set 11 | korla
# Processing Record 38 of Set 11 | kenitra
# Processing Record 39 of Set 11 | hami
# Processing Record 40 of Set 11 | ariquemes
# Processing Record 41 of Set 11 | vao
# Processing Record 42 of Set 11 | ndele
# Processing Record 43 of Set 11 | maneadero
# Processing Record 44 of Set 11 | pisco
# Processing Record 45 of Set 11 | barcarena
# Processing Record 46 of Set 11 | muncar
# Processing Record 47 of Set 11 | magadan
# Processing Record 48 of Set 11 | chaa-khol
# City not found. Skipping...
# Processing Record 49 of Set 11 | valverde del camino
# Processing Record 50 of Set 11 | conakry
# Processing Record 1 of Set 12 | kupang
# Processing Record 2 of Set 12 | coari
# Processing Record 3 of Set 12 | kieta
# Processing Record 4 of Set 12 | xuanhua
# Processing Record 5 of Set 12 | luena
# Processing Record 6 of Set 12 | marienburg
# Processing Record 7 of Set 12 | jishu
# Processing Record 8 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 10 of Set 12 | jinzhou
# Processing Record 11 of Set 12 | mgandu
# Processing Record 12 of Set 12 | vanimo
# Processing Record 13 of Set 12 | barcelos
# Processing Record 14 of Set 12 | namibe
# Processing Record 15 of Set 12 | manado
# Processing Record 16 of Set 12 | zachary
# Processing Record 17 of Set 12 | broadstairs
# Processing Record 18 of Set 12 | teguldet
# Processing Record 19 of Set 12 | pierre
# Processing Record 20 of Set 12 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 21 of Set 12 | podor
# Processing Record 22 of Set 12 | polunochnoye
# Processing Record 23 of Set 12 | ahuimanu
# Processing Record 24 of Set 12 | baracoa
# Processing Record 25 of Set 12 | karaton
# Processing Record 26 of Set 12 | tilichiki
# Processing Record 27 of Set 12 | mantua
# Processing Record 28 of Set 12 | monte patria
# Processing Record 29 of Set 12 | verkhnetulomskiy
# Processing Record 30 of Set 12 | urengoy
# Processing Record 31 of Set 12 | san ignacio
# Processing Record 32 of Set 12 | ketchikan
# Processing Record 33 of Set 12 | vestmanna
# Processing Record 34 of Set 12 | areia branca
# Processing Record 35 of Set 12 | rodrigues alves
# Processing Record 36 of Set 12 | belmonte
# Processing Record 37 of Set 12 | coffs harbour
# Processing Record 38 of Set 12 | kansanshi
# Processing Record 39 of Set 12 | rusape
# Processing Record 40 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 12 | san buenaventura
# Processing Record 42 of Set 12 | sampit
# Processing Record 43 of Set 12 | obregon
# Processing Record 44 of Set 12 | ubala
# Processing Record 45 of Set 12 | doha
# Processing Record 46 of Set 12 | road town
# Processing Record 47 of Set 12 | manthani
# Processing Record 48 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 49 of Set 12 | troitskoye
# Processing Record 50 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 13 | kjollefjord
# Processing Record 2 of Set 13 | mitu
# Processing Record 3 of Set 13 | hokitika
# Processing Record 4 of Set 13 | puri
# Processing Record 5 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 13 | andenes
# Processing Record 7 of Set 13 | mezen
# Processing Record 8 of Set 13 | dwarka
# Processing Record 9 of Set 13 | lodeynoye pole
# Processing Record 10 of Set 13 | fortuna foothills
# Processing Record 11 of Set 13 | egvekinot
# Processing Record 12 of Set 13 | steamboat springs
# Processing Record 13 of Set 13 | pangody
# Processing Record 14 of Set 13 | kingaroy
# Processing Record 15 of Set 13 | pombia
# Processing Record 16 of Set 13 | bontang
# Processing Record 17 of Set 13 | letka
# Processing Record 18 of Set 13 | chulman
# Processing Record 19 of Set 13 | jibuti
# Processing Record 20 of Set 13 | svetlyy
# Processing Record 21 of Set 13 | hundorp
# Processing Record 22 of Set 13 | gerash
# Processing Record 23 of Set 13 | makakilo city
# Processing Record 24 of Set 13 | brae
# Processing Record 25 of Set 13 | meulaboh
# Processing Record 26 of Set 13 | cozumel
# Processing Record 27 of Set 13 | port hardy
# Processing Record 28 of Set 13 | bay roberts
# Processing Record 29 of Set 13 | sungaipenuh
# Processing Record 30 of Set 13 | nishihara
# Processing Record 31 of Set 13 | iquique
# Processing Record 32 of Set 13 | traverse city
# Processing Record 33 of Set 13 | lhokseumawe
# Processing Record 34 of Set 13 | sinnamary
# Processing Record 35 of Set 13 | batemans bay
# Processing Record 36 of Set 13 | lethem
# Processing Record 37 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 38 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 13 | mehamn
# Processing Record 40 of Set 13 | rawson
# Processing Record 41 of Set 13 | pilar
# Processing Record 42 of Set 13 | suihua
# Processing Record 43 of Set 13 | kvareli
# Processing Record 44 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 13 | vozhega
# Processing Record 46 of Set 13 | xining
# Processing Record 47 of Set 13 | bereda
# Processing Record 48 of Set 13 | heishan
# Processing Record 49 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 13 | pahrump
# Processing Record 1 of Set 14 | tornabe
# Processing Record 2 of Set 14 | wajima
# Processing Record 3 of Set 14 | malindi
# Processing Record 4 of Set 14 | mount isa
# Processing Record 5 of Set 14 | pirapo
# Processing Record 6 of Set 14 | farafangana
# Processing Record 7 of Set 14 | karratha
# Processing Record 8 of Set 14 | nova odesa
# Processing Record 9 of Set 14 | kroya
# Processing Record 10 of Set 14 | kavaratti
# Processing Record 11 of Set 14 | lisakovsk
# Processing Record 12 of Set 14 | kemijarvi
# Processing Record 13 of Set 14 | dahra
# Processing Record 14 of Set 14 | jurm
# Processing Record 15 of Set 14 | molina
# Processing Record 16 of Set 14 | vegreville
# Processing Record 17 of Set 14 | uray
# Processing Record 18 of Set 14 | san ramon
# Processing Record 19 of Set 14 | preobrazheniye
# Processing Record 20 of Set 14 | xinxiang
# Processing Record 21 of Set 14 | jiehu
# Processing Record 22 of Set 14 | bilma
# Processing Record 23 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 24 of Set 14 | aquiraz
# Processing Record 25 of Set 14 | ilebo
# Processing Record 26 of Set 14 | kamarion
# Processing Record 27 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 28 of Set 14 | machinga
# Processing Record 29 of Set 14 | olinda
# Processing Record 30 of Set 14 | porto murtinho
# Processing Record 31 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 32 of Set 14 | mutoko
# Processing Record 33 of Set 14 | herat
# Processing Record 34 of Set 14 | terney
# Processing Record 35 of Set 14 | mareeba
# Processing Record 36 of Set 14 | rio grande
# Processing Record 37 of Set 14 | villa carlos paz
# Processing Record 38 of Set 14 | grand gaube
# Processing Record 39 of Set 14 | sabaudia
# Processing Record 40 of Set 14 | ormara
# Processing Record 41 of Set 14 | ilhabela
# Processing Record 42 of Set 14 | bonavista
# Processing Record 43 of Set 14 | springbok
# Processing Record 44 of Set 14 | zyryanka
# Processing Record 45 of Set 14 | kyren
# Processing Record 46 of Set 14 | ugoofaaru
# Processing Record 47 of Set 14 | yulara
# Processing Record 48 of Set 14 | tarbes
# Processing Record 49 of Set 14 | les cayes
# Processing Record 50 of Set 14 | hailar
# Processing Record 1 of Set 15 | oyama
# Processing Record 2 of Set 15 | taungdwingyi
# Processing Record 3 of Set 15 | kawalu
# Processing Record 4 of Set 15 | bezhetsk
# Processing Record 5 of Set 15 | huarmey
# Processing Record 6 of Set 15 | disa
# Processing Record 7 of Set 15 | bulgan
# Processing Record 8 of Set 15 | vilyuysk
# Processing Record 9 of Set 15 | rovaniemi
# Processing Record 10 of Set 15 | ivanovka
# Processing Record 11 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 12 of Set 15 | yomou
# Processing Record 13 of Set 15 | komsomolskiy
# Processing Record 14 of Set 15 | sangar
# Processing Record 15 of Set 15 | mkokotoni
# Processing Record 16 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 15 | mildura
# Processing Record 18 of Set 15 | san jeronimo
# Processing Record 19 of Set 15 | jilmah
# City not found. Skipping...
# Processing Record 20 of Set 15 | goure
# Processing Record 21 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 15 | samarai
# Processing Record 24 of Set 15 | yellandu
# Processing Record 25 of Set 15 | chadan
# Processing Record 26 of Set 15 | miraflores
# Processing Record 27 of Set 15 | tuscaloosa
# Processing Record 28 of Set 15 | oranjemund
# Processing Record 29 of Set 15 | tarauaca
# Processing Record 30 of Set 15 | dibaya
# City not found. Skipping...
# Processing Record 31 of Set 15 | surami
# Processing Record 32 of Set 15 | carcassonne
# Processing Record 33 of Set 15 | pontes e lacerda
# Processing Record 34 of Set 15 | banda aceh
# Processing Record 35 of Set 15 | careiro da varzea
# Processing Record 36 of Set 15 | pitimbu
# Processing Record 37 of Set 15 | fare
# Processing Record 38 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 15 | cazaje
# City not found. Skipping...
# Processing Record 41 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 15 | botngard
# Processing Record 43 of Set 15 | avera
# Processing Record 44 of Set 15 | burgeo
# Processing Record 45 of Set 15 | guanare
# Processing Record 46 of Set 15 | la ronge
# Processing Record 47 of Set 15 | hurricane
# Processing Record 48 of Set 15 | deniliquin
# Processing Record 49 of Set 15 | altay
# Processing Record 50 of Set 15 | feicheng
# Processing Record 1 of Set 16 | hvolsvollur
# Processing Record 2 of Set 16 | bethanien
# Processing Record 3 of Set 16 | verkhnyaya inta
# Processing Record 4 of Set 16 | hounde
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 681

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Thompson  55.7435  -97.8558     19.56        93         100
# 1    Medicine Hat  50.0501 -110.6683     37.83        70          75
# 2         Ushuaia -54.8000  -68.3000     44.26        93          40
# 3          Avarua -21.2078 -159.7750     78.85        65          40
# 4   Mar Del Plata -38.0023  -57.5575     61.09        86          20
# 5  Ribeira Grande  38.5167  -28.7000     64.78        87         100
# 6           Kapaa  22.0752 -159.3190     85.98        84          75
# 7     Yellowknife  62.4560 -114.3525     10.92        85          75
# 8        Griffith  41.5284  -87.4237     71.89        63           0
# 9         Bairiki   1.3292  172.9752     86.00        74          20
#
#    Wind Speed Country
# 0        5.75      CA
# 1        9.22      CA
# 2        8.05      AR
# 3       20.71      CK
# 4       21.99      AR
# 5        5.01      PT
# 6       10.36      US
# 7       10.36      CA
# 8       21.85      US
# 9        9.22      KI

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Thompson      CA  55.7435  -97.8558     19.56        93         100
# 1   Medicine Hat      CA  50.0501 -110.6683     37.83        70          75
# 2        Ushuaia      AR -54.8000  -68.3000     44.26        93          40
# 3         Avarua      CK -21.2078 -159.7750     78.85        65          40
# 4  Mar Del Plata      AR -38.0023  -57.5575     61.09        86          20
#
#    Wind Speed
# 0        5.75
# 1        9.22
# 2        8.05
# 3       20.71
# 4       21.99

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
